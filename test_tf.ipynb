# %%
import tensorflow as tf
import numpy as np
import tensorboard

# %%
x = tf.constant([[2,1,4,3],[1,2,3,4],[4,3,2,1]])
# Out:
# <tf.Tensor: id=25, shape=(3, 4), dtype=int32, numpy=
# array([[2, 1, 4, 3],
#        [1, 2, 3, 4],
#        [4, 3, 2, 1]])>
